# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from numpy import array
import matplotlib

# %%
med = pd.read_csv(open('/Users/Deb/Desktop/FIPSAsthmaCounty.csv'), sep=',')
med
# Out:
#    ﻿COUNTY (OR GROUP)  Percent with Active Asthma   FIPS
# 0                Amador                          8.7  6005
# 1                Colusa                         13.7  6011
# 2                  Inyo                          8.7  6027
# 3               Alameda                          9.8  6001
# 4                Alpine                          8.7  6003
# 5                 Butte                          9.7  6007
# 6            Calaveras                           8.7  6009
# 7          Contra Costa                          9.6  6013
# 8             Del Norte                          9.2  6015
# 9             El Dorado                          8.3  6017
# 10               Fresno                         11.3  6019
# 11                Glenn                         13.7  6021
# 12             Humboldt                          7.0  6023
# 13             Imperial                          9.5  6025
# 14                 Kern                         11.9  6029
# ...
